# %%
# %run interface.ipynb

# %%
test1 = [
    Point(1, 1),
    Point(1, 10),
    Point(10, 1),
    Point(10, 10),
    Point(2, 3),
    Point(4, 5),
    Point(6, 7),
    Point(8, 9),
    Point(3, 4),
    Point(5, 6),
    Point(7, 8),
    Point(9, 2),
    Point(3, 7),
    Point(6, 3),
    Point(8, 4)
]
